# %% [markdown]
# Name : Abhay Swarnkar

# %% [markdown]
# # Internship From TechnoHacks Internships

# %% [markdown]
# We're Going to take the following approach

# %% [markdown]
# Github: https://github.com/GENRATECODE/Technohack

# %% [markdown]
# #  Task 1: House Price Prediction

# %% [markdown]
# ## Author- Abhay Swarnkar

# %% [markdown]
# # 1.  Problem Definition

# %% [markdown]
# In a statement
#
# * The Ames Housing dataset was compiled by Dean De Cock for use in data science education. It's an incredible alternative for data scientists looking for a modernized and expanded version of the often cited Boston Housing dataset.
#
# * It is your job to predict the sales price for each house. For each Id in the test set, you must predict the value of the SalePrice variable.

# %% [markdown]
# # 2. Data

# %% [markdown]
# Data sets:  https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data

# %% [markdown]
# # 3. Evaluation

# %% [markdown]
# Submissions are evaluated on Root-Mean-Squared-Error (RMSE) between the logarithm of the predicted value and the logarithm of the observed sales price. (Taking logs means that errors in predicting expensive houses and cheap houses will affect the result equally.)

# %% [markdown]
# # 4. Features and Tuning  Model

# %% [markdown]
# Creative feature engineering
#
# Advanced regression techniques like random forest and gradient boosting

# %% [markdown]
# # 2. Data

# %% [markdown]
# ## Data set column describe

# %% [markdown]
# ID:
#
#
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
#        RP	Residential Low Density Park
#        RM	Residential Medium Density
#
# LotFrontage: Linear feet of street connected to property
#
# LotArea: Lot size in square feet
#
# Street: Type of road access to property
#
#        Grvl	Gravel
#        Pave	Paved
#
# Alley: Type of alley access to property
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access
#
# LotShape: General shape of property
#
#        Reg	Regular
#        IR1	Slightly irregular
#        IR2	Moderately Irregular
#        IR3	Irregular
#
# LandContour: Flatness of the property
#
#        Lvl	Near Flat/Level
#        Bnk	Banked - Quick and significant rise from street grade to building
#        HLS	Hillside - Significant slope from side to side
#        Low	Depression
#
# Utilities: Type of utilities available
#
#        AllPub	All public Utilities (E,G,W,& S)
#        NoSewr	Electricity, Gas, and Water (Septic Tank)
#        NoSeWa	Electricity and Gas Only
#        ELO	Electricity only
#
# LotConfig: Lot configuration
#
#        Inside	Inside lot
#        Corner	Corner lot
#        CulDSac	Cul-de-sac
#        FR2	Frontage on 2 sides of property
#        FR3	Frontage on 3 sides of property
#
# LandSlope: Slope of property
#
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
#
# Neighborhood: Physical locations within Ames city limits
#
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker
#
# Condition1: Proximity to various conditions
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# Condition2: Proximity to various conditions (if more than one is present)
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# BldgType: Type of dwelling
#
#        1Fam	Single-family Detached
#        2FmCon	Two-family Conversion; originally built as one-family dwelling
#        Duplx	Duplex
#        TwnhsE	Townhouse End Unit
#        TwnhsI	Townhouse Inside Unit
#
# HouseStyle: Style of dwelling
#
#        1Story	One story
#        1.5Fin	One and one-half story: 2nd level finished
#        1.5Unf	One and one-half story: 2nd level unfinished
#        2Story	Two story
#        2.5Fin	Two and one-half story: 2nd level finished
#        2.5Unf	Two and one-half story: 2nd level unfinished
#        SFoyer	Split Foyer
#        SLvl	Split Level
#
# OverallQual: Rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# OverallCond: Rates the overall condition of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# YearBuilt: Original construction date
#
# YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)
#
# RoofStyle: Type of roof
#
#        Flat	Flat
#        Gable	Gable
#        Gambrel	Gabrel (Barn)
#        Hip	Hip
#        Mansard	Mansard
#        Shed	Shed
#
# RoofMatl: Roof material
#
#        ClyTile	Clay or Tile
#        CompShg	Standard (Composite) Shingle
#        Membran	Membrane
#        Metal	Metal
#        Roll	Roll
#        Tar&Grv	Gravel & Tar
#        WdShake	Wood Shakes
#        WdShngl	Wood Shingles
#
# Exterior1st: Exterior covering on house
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# Exterior2nd: Exterior covering on house (if more than one material)
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# MasVnrType: Masonry veneer type
#
#        BrkCmn	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        None	None
#        Stone	Stone
#
# MasVnrArea: Masonry veneer area in square feet
#
# ExterQual: Evaluates the quality of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# ExterCond: Evaluates the present condition of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# Foundation: Type of foundation
#
#        BrkTil	Brick & Tile
#        CBlock	Cinder Block
#        PConc	Poured Contrete
#        Slab	Slab
#        Stone	Stone
#        Wood	Wood
#
# BsmtQual: Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement
#
# BsmtCond: Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement
#
# BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
#
# BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF1: Type 1 finished square feet
#
# BsmtFinType2: Rating of basement finished area (if multiple types)
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF2: Type 2 finished square feet
#
# BsmtUnfSF: Unfinished square feet of basement area
#
# TotalBsmtSF: Total square feet of basement area
#
# Heating: Type of heating
#
#        Floor	Floor Furnace
#        GasA	Gas forced warm air furnace
#        GasW	Gas hot water or steam heat
#        Grav	Gravity furnace
#        OthW	Hot water or steam heat other than gas
#        Wall	Wall furnace
#
# HeatingQC: Heating quality and condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# CentralAir: Central air conditioning
#
#        N	No
#        Y	Yes
#
# Electrical: Electrical system
#
#        SBrkr	Standard Circuit Breakers & Romex
#        FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
#        FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
#        FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
#        Mix	Mixed
#
# 1stFlrSF: First Floor square feet
#
# 2ndFlrSF: Second floor square feet
#
# LowQualFinSF: Low quality finished square feet (all floors)
#
# GrLivArea: Above grade (ground) living area square feet
#
# BsmtFullBath: Basement full bathrooms
#
# BsmtHalfBath: Basement half bathrooms
#
# FullBath: Full bathrooms above grade
#
# HalfBath: Half baths above grade
#
# Bedroom: Bedrooms above grade (does NOT include basement bedrooms)
#
# Kitchen: Kitchens above grade
#
# KitchenQual: Kitchen quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
#        Typ	Typical Functionality
#        Min1	Minor Deductions 1
#        Min2	Minor Deductions 2
#        Mod	Moderate Deductions
#        Maj1	Major Deductions 1
#        Maj2	Major Deductions 2
#        Sev	Severely Damaged
#        Sal	Salvage only
#
# Fireplaces: Number of fireplaces
#
# FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace
#
# GarageType: Garage location
#
#        2Types	More than one type of garage
#        Attchd	Attached to home
#        Basment	Basement Garage
#        BuiltIn	Built-In (Garage part of house - typically has room above garage)
#        CarPort	Car Port
#        Detchd	Detached from home
#        NA	No Garage
#
# GarageYrBlt: Year garage was built
#
# GarageFinish: Interior finish of the garage
#
#        Fin	Finished
#        RFn	Rough Finished
#        Unf	Unfinished
#        NA	No Garage
#
# GarageCars: Size of garage in car capacity
#
# GarageArea: Size of garage in square feet
#
# GarageQual: Garage quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# GarageCond: Garage condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# PavedDrive: Paved driveway
#
#        Y	Paved
#        P	Partial Pavement
#        N	Dirt/Gravel
#
# WoodDeckSF: Wood deck area in square feet
#
# OpenPorchSF: Open porch area in square feet
#
# EnclosedPorch: Enclosed porch area in square feet
#
# 3SsnPorch: Three season porch area in square feet
#
# ScreenPorch: Screen porch area in square feet
#
# PoolArea: Pool area in square feet
#
# PoolQC: Pool quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        NA	No Pool
#
# Fence: Fence quality
#
#        GdPrv	Good Privacy
#        MnPrv	Minimum Privacy
#        GdWo	Good Wood
#        MnWw	Minimum Wood/Wire
#        NA	No Fence
#
# MiscFeature: Miscellaneous feature not covered in other categories
#
#        Elev	Elevator
#        Gar2	2nd Garage (if not described in garage section)
#        Othr	Other
#        Shed	Shed (over 100 SF)
#        TenC	Tennis Court
#        NA	None
#
# MiscVal: $Value of miscellaneous feature
#
# MoSold: Month Sold (MM)
#
# YrSold: Year Sold (YYYY)
#
# SaleType: Type of sale
#
#        WD 	Warranty Deed - Conventional
#        CWD	Warranty Deed - Cash
#        VWD	Warranty Deed - VA Loan
#        New	Home just constructed and sold
#        COD	Court Officer Deed/Estate
#        Con	Contract 15% Down payment regular terms
#        ConLw	Contract Low Down payment and low interest
#        ConLI	Contract Low Interest
#        ConLD	Contract Low Down
#        Oth	Other
#
# SaleCondition: Condition of sale
#
#
#        Normal	Normal Sale
#        Abnorml	Abnormal Sale -  trade, foreclosure, short sale
#        AdjLand	Adjoining Land Purchase
#        Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage
#
# unit
#
#
#        Family	Sale between family members
#        Partial	Home was not completed when last assessed (associated with New Homes)

# %% [markdown]
# Steps:
# 1. Data Import
#
# 2. Data Processoning
#
# 3. Model Selection
#
# 4. Model evaluation
#
# 5. Hyper Parameter Tuning
#
# 6. Deploy Model

# %% [markdown]
# # 1. Preparing the tools

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %% [markdown]
# ### Load data

# %%
df=pd.read_csv("data_house_prediction/train.csv")
df.shape # (Rows, columns )
# Out:
# (1460, 81)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df["SalePrice"].value_counts().plot(kind="bar",figsize=(100,200));

# %%
df["SalePrice"].hist(bins=10)
# Out:
# <Axes: >

# %%
df["Alley"].value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %%
df["MSSubClass"].value_counts()
# Out:
# MSSubClass
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: count, dtype: int64

# %%
df["MSZoning"].value_counts()
# Out:
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df=df.drop(["Id"],axis=1)

# %%
df.head().T
# Out:
#                     0       1       2        3       4
# MSSubClass         60      20      60       70      60
# MSZoning           RL      RL      RL       RL      RL
# LotFrontage      65.0    80.0    68.0     60.0    84.0
# LotArea          8450    9600   11250     9550   14260
# Street           Pave    Pave    Pave     Pave    Pave
# ...               ...     ...     ...      ...     ...
# MoSold              2       5       9        2      12
# YrSold           2008    2007    2008     2006    2008
# SaleType           WD      WD      WD       WD      WD
# SaleCondition  Normal  Normal  Normal  Abnorml  Normal
# SalePrice      208500  181500  223500   140000  250000
#
# [80 rows x 5 columns]

# %%
for label, content in df.items():
    if pd.isna(content).any():
        print(label)

# %% [markdown]
# # Filling Missing value in House Price Prediction

# %% [markdown]
# #### LotFrontage

# %%
# # fill value in LotFrontage 
df.LotFrontage.fillna(df.LotFrontage.mean(),inplace=True)

# %% [markdown]
#   Grvl	Gravel ->0
#
#   Pave	Paved ->1
#
#   NA 	No alley access ->2

# %% [markdown]
# #### Alley

# %%
# Fill missing value in Alley and change into Number  
df['Alley'].fillna("NA", inplace=True)
# Define the mapping
mapping = {'Grvl': 0, 'Pave': 1, 'NA': 2}

# Create a new column with the integer values
df['Alley'] = df['Alley'].map(mapping)

# %%
df.Alley.value_counts()
# Out:
# Alley
# 2    1369
# 0      50
# 1      41
# Name: count, dtype: int64

# %% [markdown]
# #### MasVnrType: Masonry veneer type
#
#    BrkCmn	Brick Common
#
#    BrkFace	Brick Face
#
#    CBlock	Cinder Block
#
#    None	None
#
#    Stone	Stone

# %%
# Fill Missing value of MasVnrType
# Fill missing value inplace NA
df['MasVnrType'].fillna("NA", inplace=True)
# create a dict to change that 
mapping={"BrkCmn":0,"BrkFace":1, "CBlock":3,"NA":4,"Stone":5}
df["MasVnrType"]=df["MasVnrType"].map(mapping)

# %%
# Fill MasVnrArea
df["MasVnrArea"].fillna(df["MasVnrArea"].median(),inplace=True)

# %% [markdown]
# #### BsmtQual: Evaluates the height of the basement
#
#    Ex	Excellent (100+ inches) -1
#
#    Gd	Good (90-99 inches) -2
#
#    TA	Typical (80-89 inches) 3
#
#    Fa	Fair (70-79 inches) 4
#
#    Po	Poor (<70 inches) 5
#
#    NA	No Basement 6

# %%
# mapping and convert into number 
df["BsmtQual"].fillna("NA",inplace=True)
mapping ={"Ex":1,
          "Gd":2,
          "TA":3,
          "Fa":4,
          "Po":5,
          "NA":6}
# Map value in BsmtQual
df["BsmtQual"]=df["BsmtQual"].map(mapping)

# %%
df["BsmtQual"].value_counts()
# Out:
# BsmtQual
# 3    649
# 2    618
# 1    121
# 6     37
# 4     35
# Name: count, dtype: int64

# %% [markdown]
# #### BsmtCond: Evaluates the general condition of the basement
#
#    Ex	Excellent
#
#    Gd	Good
#
#    TA	Typical - slight dampness allowed
#
#    Fa	Fair - dampness or some cracking or settling
#
#    Po	Poor - Severe cracking, settling, or wetness
#
#    NA	No Basement

# %%
# mapping and convert into number 
df["BsmtCond"].fillna("NA",inplace=True)
mapping ={"Ex":1,
          "Gd":2,
          "TA":3,
          "Fa":4,
          "Po":5,
          "NA":6}
# Map value in BsmtQual
df["BsmtCond"]=df["BsmtCond"].map(mapping)

# %% [markdown]
# #### BsmtExposure: Refers to walkout or garden level walls
#
#    Gd	Good Exposure
#
#    Av	Average Exposure (split levels or foyers typically score average or above)
#
#    Mn	Mimimum Exposure
#
#    No	No Exposure
#
#    NA	No Basement

# %%
# mapping and convert into number 
df["BsmtExposure"].fillna("NA",inplace=True)
mapping ={
          "Gd":1,
          "Av":2,
          "Mn":3,
          "No":4,
          "NA":5}
# Map value in BsmtQual
df["BsmtExposure"]=df["BsmtExposure"].map(mapping)

# %% [markdown]
# #### For BsmtFinType1  change to numerical and fill missing value
#
# BsmtFinType1: Rating of basement finished area
#
#    GLQ	Good Living Quarters
#
#    ALQ	Average Living Quarters
#
#    BLQ	Below Average Living Quarters
#
#    Rec	Average Rec Room
#
#    LwQ	Low Quality
#
#    Unf	Unfinshed
#
#    NA	No Basement

# %%
# mapping and convert into number 
df["BsmtFinType1"].fillna(value="NA",inplace=True)

# make mapping variable
mapping={"GLQ":0,
   "ALQ":1,
   "BLQ":2,
   "Rec":3,
   "LwQ":4,
   "Unf":5,
   "NA":6}
# Map value in BsmtQual
df["BsmtFinType1"]=df["BsmtFinType1"].map(mapping)

# %% [markdown]
# ### BsmtFinType2: Rating of basement finished area (if multiple types)
#
#    GLQ	Good Living Quarters
#
#    ALQ	Average Living Quarters
#
#    BLQ	Below Average Living Quarters
#
#    Rec	Average Rec Room
#
#    LwQ	Low Quality
#
#    Unf	Unfinshed
#
#    NA	No Basement

# %%
# mapping and convert into number 
df["BsmtFinType2"].fillna(value="NA",inplace=True)

# make mapping variable
mapping={"GLQ":0,
   "ALQ":1,
   "BLQ":2,
   "Rec":3,
   "LwQ":4,
   "Unf":5,
   "NA":6}
# Map value in BsmtQual
df["BsmtFinType2"]=df["BsmtFinType2"].map(mapping)

# %% [markdown]
# #### Electrical:  Electrical System
# Electrical: Electrical system
#
#    SBrkr	Standard Circuit Breakers & Romex
#
#    FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
#
#    FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
#
#    FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
#
#    Mix	Mixed

# %%
df.Electrical.fillna("NA",inplace=True)

# %%
mapping={"SBrkr":0,
         "FuseA":1,
         "FuseF":2,
         "FuseP":3,
         "Mix":4,
         "NA":0
        }
df["Electrical"]=df.Electrical.map(mapping)

# %%
df.Electrical.value_counts()
# Out:
# Electrical
# 0    1335
# 1      94
# 2      27
# 3       3
# 4       1
# Name: count, dtype: int64

# %% [markdown]
# #### FireplaceQu: Fireplace quality
#
#    Ex	Excellent - Exceptional Masonry Fireplace
#
#    Gd	Good - Masonry Fireplace in main level
#
#    TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#
#    Fa	Fair - Prefabricated Fireplace in basement
#
#    Po	Poor - Ben Franklin Stove
#
#    NA	No Fireplace

# %%
df.FireplaceQu.fillna("NA",inplace=True)

# %%
mapping={"Ex":0,
        "Gd":1,
        "TA":2,
        "Fa":3,
        "Po":4,
        "NA":5}
df["FireplaceQu"]=df.FireplaceQu.map(mapping)

# %% [markdown]
# #### GarageType: Garage location
#
#    2Types	More than one type of garage
#
#    Attchd	Attached to home
#
#    Basment	Basement Garage
#
#    BuiltIn	Built-In (Garage part of house - typically has room above garage)
#
#    CarPort	Car Port
#
#    Detchd	Detached from home
#
#    NA	No Garage

# %%
df.GarageType.fillna("NA",inplace=True)

# %%
df.GarageType.value_counts()
# Out:
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# NA          81
# Basment     19
# CarPort      9
# 2Types       6
# Name: count, dtype: int64

# %%
mapping={"2Types":0,
        "Attchd":1,
        "Basment":2,
        "BuiltIn":3,
        "CarPort":4,
        "Detchd":5,
        "NA":6}
df["GarageType"]=df.GarageType.map(mapping)
df["GarageType"].value_counts()
# Out:
# GarageType
# 1    870
# 5    387
# 3     88
# 6     81
# 2     19
# 4      9
# 0      6
# Name: count, dtype: int64

# %% [markdown]
# #### GarageYrBlt: Year garage was built

# %%
df.GarageYrBlt.fillna(df.GarageYrBlt.median(),inplace=True)

# %%
df.GarageYrBlt.median()
# Out:
# 1980.0

# %%
df.GarageYrBlt.isna().value_counts()
# Out:
# GarageYrBlt
# False    1460
# Name: count, dtype: int64

# %% [markdown]
# #### GarageFinish: Interior finish of the garage
#
#    Fin	Finished
#
#    RFn	Rough Finished
#
#    Unf	Unfinished
#
#    NA	No Garage

# %%
df["GarageFinish"].fillna("NA",inplace=True)

# %%
mapping={"Fin": 0,
         "RFn" :1,
         "Unf": 2,
         "NA" :3}
df["GarageFinish"]=df["GarageFinish"].map(mapping)

# %% [markdown]
# #### GarageQual: Garage quality
#
#    Ex	Excellent
#
#    Gd	Good
#
#    TA	Typical/Average
#
#    Fa	Fair
#
#    Po	Poor
#
#    NA	No Garage

# %%
df.GarageQual.fillna("NA",inplace=True)

# %%
df.GarageQual.value_counts()
# Out:
# GarageQual
# TA    1311
# NA      81
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: count, dtype: int64

# %%
mapping={"Ex": 0,
         "Gd": 1,
         "TA": 2,
         "Fa": 3,
         "Po": 4,
         "NA":5}
df["GarageQual"]=df["GarageQual"].map(mapping)

# %% [markdown]
# #### GarageCond: Garage condition
#
#    Ex	Excellent
#
#    Gd	Good
#
#    TA	Typical/Average
#
#    Fa	Fair
#
#    Po	Poor
#
#    NA	No Garage

# %%
df.GarageCond.fillna("NA",inplace=True)

# %%
mapping={"Ex": 0,
         "Gd": 1,
         "TA": 2,
         "Fa": 3,
         "Po": 4,
         "NA":5}
df["GarageCond"]=df["GarageCond"].map(mapping)

# %% [markdown]
# #### PoolQC: Pool quality
#
#    Ex	Excellent
#
#    Gd	Good
#
#    TA	Average/Typical
#
#    Fa	Fair
#
#    NA	No Pool

# %%
df.PoolQC.fillna("NA",inplace=True)

# %%
mapping={"Ex": 0,
         "Gd": 1,
         "TA": 2,
         "Fa": 3,
         "NA":4}
df["PoolQC"]=df["PoolQC"].map(mapping)

# %%
df.PoolQC.value_counts()
# Out:
# PoolQC
# 4    1453
# 1       3
# 0       2
# 3       2
# Name: count, dtype: int64

# %% [markdown]
# #### Fence: Fence quality
#
#    GdPrv	Good Privacy
#
#    MnPrv	Minimum Privacy
#
#    GdWo	Good Wood
#
#    MnWw	Minimum Wood/Wire
#
#    NA	No Fence

# %%
df.Fence.fillna("NA",inplace=True)

# %%
mapping={"GdPrv": 0,
         "MnPrv": 1,
         "GdWo": 2,
         "MnWw":3,
         "NA" :4,}
df["Fence"]=df.Fence.map(mapping)

# %% [markdown]
# #### MiscFeature: Miscellaneous feature not covered in other categories
#
#    Elev	Elevator
#
#    Gar2	2nd Garage (if not described in garage section)
#
#    Othr	Other
#
#    Shed	Shed (over 100 SF)
#
#    TenC	Tennis Court
#
#    NA	None

# %%
df.MiscFeature.fillna("NA",inplace=True)

# %%
mapping={"Elev": 0,
         "Gar2": 1,
         "Othr" :2,
         "Shed":3,
         "TenC":4,
         "NA": 5}
df["MiscFeature"]=df.MiscFeature.map(mapping)

# %% [markdown]
# ### Filling and turning categorical variables to numbers
# Now we've filled the numeric values, we'll do the same with the categorical values at the same time as turning them into numbers.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# Check columns which *aren't* numeric
for label, content in df.items():
    if not pd.api.types.is_numeric_dtype(content):
        
        print(label)
# Out:
# MSZoning
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# ExterQual
# ExterCond
# Foundation
# Heating
# HeatingQC
# CentralAir
# KitchenQual
# Functional
# PavedDrive
# SaleType
# SaleCondition

# %%
# Turn categorical variables into numbers
for label, content in df.items():
    # Check columns which *aren't* numeric
    if not pd.api.types.is_numeric_dtype(content):
        # We add the +1 because pandas encodes missing categories as -1
        df[label] = pd.Categorical(content).codes+1

# %%
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   1          60         4         65.0     8450       2      2         4
# 1   2          20         4         80.0     9600       2      2         4
# 2   3          60         4         68.0    11250       2      2         1
# 3   4          70         4         60.0     9550       2      2         1
# 4   5          60         4         84.0    14260       2      2         1
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0            4          1  ...         0       4      4            5        0
# 1            4          1  ...         0       4      4            5        0
# 2            4          1  ...         0       4      4            5        0
# 3            4          1  ...         0       4      4            5        0
# 4            4          1  ...         0       4      4            5        0
#
# ...

# %% [markdown]
# Now all of our data is numeric and there are no missing values, we should be able to build a machine learning model!

# %% [markdown]
# # Splitting data into train/valid sets

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int8
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int8
#  6   Alley          1460 non-null   int64
#  7   LotShape       1460 non-null   int8
#  8   LandContour    1460 non-null   int8
#  9   Utilities      1460 non-null   int8
#  10  LotConfig      1460 non-null   int8
#  11  LandSlope      1460 non-null   int8
#  12  Neighborhood   1460 non-null   int8
#  13  Condition1     1460 non-null   int8
#  14  Condition2     1460 non-null   int8
#  15  BldgType       1460 non-null   int8
#  16  HouseStyle     1460 non-null   int8
#  17  OverallQual    1460 non-null   int64
# ...

# %%
data=df

# %%
len(data)
# Out:
# 1460

# %%
train_df=data[:1159]
val_df=data[1160:]
len(train_df),len(val_df)
# Out:
# (1159, 300)

# %%
# Split data into X& y
x_train,y_train=train_df.drop("SalePrice",axis=1),train_df.SalePrice
x_vaild,y_valid=val_df.drop("SalePrice",axis=1), val_df.SalePrice
x_train.shape,y_train.shape,x_vaild.shape,y_valid.shape
# Out:
# ((1159, 80), (1159,), (300, 80), (300,))

# %%
xb_train=data.drop(["SalePrice"],axis=1)
y_b_train=data["SalePrice"]
xb_train.shape,y_b_train.shape
# Out:
# ((1460, 80), (1460,))

# %% [markdown]
# # Build Model
#
# # Select Model

# %% [markdown]
# Here we used two Model
#
# * Gradient Boosting Regressor
#
# * Random Forest Regressor

# %%
# %%time
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
GBR=[]
Index=[]
RFC=[]
model_RFC=RandomForestRegressor()
model_GBR=GradientBoostingRegressor()
for i in range(10,2000,10):
    np.random.seed(i)
    # instantiate model
    model_RFC.fit(data.drop("SalePrice",axis=1),data.SalePrice)
    model_GBR.fit(data.drop("SalePrice",axis=1),data.SalePrice)
    GBR.append(model_GBR.score(data.drop("SalePrice",axis=1),data.SalePrice))
    Index.append(i)
    RFC.append(model_RFC.score(data.drop("SalePrice",axis=1),  data.SalePrice))
# Out:
# CPU times: total: 29min 37s
# Wall time: 37min 57s

# %%
print("Index"," |  GBR          |","RFR")
for i in range(len(Index)):
    if GBR[i]>0.9661 and RFC[i]>0.9837:
        print(Index[i],"  |   ",GBR[i],"|",RFC[i])
# Out:
# Index  |  GBR          | RFR
# 900   |    0.9661908158185616 | 0.983728889274991

# %%
np.random.seed()
model_RFC.score(data.drop("SalePrice",axis=1),data.SalePrice)
# Out:
# 0.9785914585080802

# %%
model_GBR.score(data.drop("SalePrice",axis=1),data.SalePrice)
# Out:
# 0.9539678908428358

# %%
df.to_csv("ProcessedData/Processed_for_training.csv",index=False)

# %% [markdown]
# # Building an evalutaion function

# %% [markdown]
# According to Kaggle for the House Price Pridiction, the evalutation function they use is root mean squared log error (RMSLE)
#
# **RMSLE** =Generally you don't care as musch if you're off by $1- as much as you'd care if you were off by 10\%, you care more about ratios rather than differences, MAE(Mean absolute error is more about exact differences)
#
# It's Import to understand evaluation metric you're going for.
#
# Since Scikit-Learn does'not have a function built in for RMSLE, we'll create our own.
#
# We can do this by taking the square root of scikit-learn's Mean_sqauared_log_error(MSLE). MSLE is the ssame as taking the log of mean squard error (MSE)
#
# We'all also calculate the MAE and R^2 for fun

# %%
from sklearn.metrics import mean_squared_log_error,mean_absolute_error
def rmsle(y_test,y_preds):
    return np.sqrt(mean_squared_log_error(y_test,y_preds))

# create function to evaluate our model

def show_scores(model):
    train_preds=model.predict(x_train)
    val_preds=model.predict(x_vaild)
    scores={
            "Training MAE": mean_absolute_error(y_train,train_preds),
            "Vaild MAE": mean_absolute_error(y_valid,val_preds),
            "Training RMSLE": rmsle(y_train,train_preds),
            "vaild RMSLE":rmsle(y_valid,val_preds),
            "Training R^2":model.score(x_train,y_train),
            "valid R^2 ": model.score(x_vaild,y_valid)
    }
    return scores

# %% [markdown]
# # Testing our model on a subset (to tune the hyperparameters)

# %% [markdown]
# Retraing an entire model would take for too long to continuing experimenting as fast as want to .
#
# So what we'll do is take a sample of training set and tune the hyperparameters on that before training a large model.
#
# If you're experiments are taking longer than 10 second(give or take how you have to wait), you should be typeig to spped things up you can spped things up by sampling less data or using a faster computer.

# %%
len(x_train),len(x_vaild)
# Out:
# (1159, 300)

# %%
# model Train
model_RFC=RandomForestRegressor()
model_GBR=GradientBoostingRegressor()
# fit model 
model_RFC.fit(x_train,y_train)
model_GBR.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
GBR=show_scores(model_GBR)
GBR
# Out:
# {'Training MAE': 10065.974786922963,
#  'Vaild MAE': 16809.48663354419,
#  'Training RMSLE': 0.08384025416081398,
#  'vaild RMSLE': 0.1330905799992702,
#  'Training R^2': 0.9700513508736196,
#  'valid R^2 ': 0.8950963987076087}

# %%
RFR=show_scores(model_RFC)
RFR
# Out:
# {'Training MAE': 6527.566583261432,
#  'Vaild MAE': 18844.845033333335,
#  'Training RMSLE': 0.05916989975197239,
#  'vaild RMSLE': 0.15364196184393006,
#  'Training R^2': 0.9797476275535439,
#  'valid R^2 ': 0.8122852832863299}

# %% [markdown]
# # Hyperparameter tuning with RandomizedSearchCV
#
# You can increase `n_iter` to try more combinations of hyperparameters but in our case, we'll try 20 and see where it gets us.
#
# Remember, we're trying to Reduce the amount of time it takes between experiments

# %%
rf_grid={"n_estimators":np.arange(10,100,10),
         "max_depth":[30,40,50],
         "min_samples_split":np.arange(2,20,2),
         "min_samples_leaf":np.arange(1,20,2),
         "max_features":[0.5,1.0,"sqrt","log2"],
         "max_samples":[100,105,106]
        }

# %%
# %time 
from sklearn.model_selection import RandomizedSearchCV
np.random.seed(900)

# Different RandomForestClassifier hyperparameters
rf_grid={"n_estimators":[70,80,90],
         "max_depth":[None,3,5,10,20,30],
         "min_samples_split":[4,5,6,8],
         "min_samples_leaf":np.arange(1,20,2),
         "max_features":[0.5,1.0,"sqrt","log2"],
         "max_samples":[100,105,106],
         "bootstrap":[True]
        }
rfr_model_tune=RandomizedSearchCV(RandomForestRegressor(),
                                 param_distributions=rf_grid,
                                 n_iter=100,
                                 cv=5,
                                 verbose=3,
                                  refit=True,
                                  n_jobs=1
                                 )
rfr_model_tune.fit(x_train,y_train)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END bootstrap=True, max_depth=3, max_features=log2, max_samples=106, min_samples_leaf=17, min_samples_split=18, n_estimators=10;, score=0.524 total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=3, max_features=log2, max_samples=106, min_samples_leaf=17, min_samples_split=18, n_estimators=10;, score=0.643 total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=3, max_features=log2, max_samples=106, min_samples_leaf=17, min_samples_split=18, n_estimators=10;, score=0.462 total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=3, max_features=log2, max_samples=106, min_samples_leaf=17, min_samples_split=18, n_estimators=10;, score=0.588 total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=3, max_features=log2, max_samples=106, min_samples_leaf=17, min_samples_split=18, n_estimators=10;, score=0.636 total time=   0.0s
# ...

# %% [markdown]
# {'Training MAE': 17765.054088089077,
#  'Vaild MAE': 20906.291928571427,
#  'Training RMSLE': 0.15399633458954,
#  'vaild RMSLE': 0.16896881669361435,
#  'Training R^2': 0.8591373049536876,
#  'valid R^2 ': 0.7723663950623677}

# %%
{'Training MAE': 17865.758528493363,
 'Vaild MAE': 21421.462369047622,
 'Training RMSLE': 0.15285162010633066,
 'vaild RMSLE': 0.17164254975606916,
 'Training R^2': 0.8579922001162404,
 'valid R^2 ': 0.7626717512165743}

# %%
show_scores(rfr_model_tune)
# Out:
# {'Training MAE': 17865.758528493363,
#  'Vaild MAE': 21421.462369047622,
#  'Training RMSLE': 0.15285162010633066,
#  'vaild RMSLE': 0.17164254975606916,
#  'Training R^2': 0.8579922001162404,
#  'valid R^2 ': 0.7626717512165743}

# %%
RandomForestRegressor(max_depth=30, max_features=0.5, max_samples=105,
                      min_samples_split=4, n_estimators=70)

# %%
RandomForestRegressor(max_depth=30, max_features=0.5, max_samples=105,
                      min_samples_split=4, n_estimators=70)

# %% [markdown]
# {'n_estimators': 70,
#  'min_samples_split': 4,
#  'min_samples_leaf': 1,
#  'max_samples': 105,
#  'max_features': 0.5,
#  'max_depth': 30,
#  'bootstrap': True}

# %%
rfr_model_tune.best_estimator_
# Out:
# RandomForestRegressor(max_depth=30, max_features=0.5, max_samples=105,
#                       min_samples_split=4, n_estimators=70)

# %%
{'n_estimators': 70,
 'min_samples_split': 4,
 'min_samples_leaf': 1,
 'max_samples': 105,
 'max_features': 0.5,
 'max_depth': 30,
 'bootstrap': True}
{'n_estimators': 70,
 'min_samples_split': 4,
 'min_samples_leaf': 1,
 'max_samples': 105,
 'max_features': 0.5,
 'max_depth': 30,
 'bootstrap': True}

# %%
rfr_model_tune.best_params_
# Out:
# {'n_estimators': 70,
#  'min_samples_split': 4,
#  'min_samples_leaf': 1,
#  'max_samples': 105,
#  'max_features': 0.5,
#  'max_depth': 30,
#  'bootstrap': True}

# %%
rfr_model_tune.best_score_
# Out:
# 0.8305486908478057

# %%
rfr_model_tune.best_params_
# Out:
# {'n_estimators': 70,
#  'min_samples_split': 4,
#  'min_samples_leaf': 1,
#  'max_samples': 105,
#  'max_features': 0.5,
#  'max_depth': 30,
#  'bootstrap': True}

# %%
rfr_model_tune.best_estimator_
# Out:
# RandomForestRegressor(max_depth=30, max_features=0.5, max_samples=105,
#                       min_samples_split=4, n_estimators=70)

# %% [markdown]
# #  Hyperparameter for Gradient Based Regression

# %% [markdown]
# learning_rate ✅
#
# max_leaf_nodes ✅
#
# 'max_depth✅
#
# max_features✅
#
# 'n_estimators✅
#
# min_samples_split✅
#
# min_samples_leaf✅

# %%
# %time 
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import GradientBoostingRegressor
np.random.seed(900)

# Different RandomForestClassifier hyperparameters
rf_grid = {
    "learning_rate": [0.01, 0.1, 0.2, 0.5, 1.0],
    "n_estimators": [ 100,200,250],
    "max_depth": [ 5, 6,7,8],
    "min_samples_split": [ 10,11,13,20],
    "min_samples_leaf": [ 1,2],
    "max_features": [0.01,0.5,1,"sqrt", "log2"]
}

gbr_model_tune = RandomizedSearchCV(
    GradientBoostingRegressor(),
    param_distributions=rf_grid,
    n_iter=100,
    cv=10,  # Increased number of folds
    verbose=3,
    refit=True,
    n_jobs=1
)
gbr_model_tune.fit(x_train,y_train)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# [CV 1/10] END learning_rate=1.0, max_depth=8, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=250;, score=0.658 total time=   2.9s
# [CV 2/10] END learning_rate=1.0, max_depth=8, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=250;, score=0.533 total time=   3.0s
# [CV 3/10] END learning_rate=1.0, max_depth=8, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=250;, score=0.620 total time=   3.1s
# [CV 4/10] END learning_rate=1.0, max_depth=8, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=250;, score=0.792 total time=   2.9s
# [CV 5/10] END learning_rate=1.0, max_depth=8, max_features=0.5, min_samples_leaf=1, min_samples_split=10, n_estimators=250;, score=0.597 total time=   2.9s
# ...

# %%
gbr_model_tune.error_score
# Out:
# nan

# %%
gbr_model_tune.best_score_
# Out:
# 0.8746185588187025

# %%
{'Training MAE': 857.1545955392119,
 'Vaild MAE': 17034.895272330894,
 'Training RMSLE': 0.008303911100441595,
 'vaild RMSLE': 0.13879589488309765,
 'Training R^2': 0.9997585502161072,
 'valid R^2 ': 0.8678322957819735}

{'Training MAE': 5251.0885301474445,
 'Vaild MAE': 16858.275284799936,
 'Training RMSLE': 0.04804987951763507,
 'vaild RMSLE': 0.13032941899191847,
 'Training R^2': 0.9918735976190582,
 'valid R^2 ': 0.8700582567658071}

{'Training MAE': 3121.02215282235,
 'Vaild MAE': 16243.452522795696,
 'Training RMSLE': 0.02809935029743241,
 'vaild RMSLE': 0.13048900094659982,
 'Training R^2': 0.9973473235784606,
 'valid R^2 ': 0.8741740270098742}
# Out:
# {'Training MAE': 5251.0885301474445,
#  'Vaild MAE': 16858.275284799936,
#  'Training RMSLE': 0.04804987951763507,
#  'vaild RMSLE': 0.13032941899191847,
#  'Training R^2': 0.9918735976190582,
#  'valid R^2 ': 0.8700582567658071}

# %%
show_scores(gbr_model_tune)
# Out:
# {'Training MAE': 3121.02215282235,
#  'Vaild MAE': 16243.452522795696,
#  'Training RMSLE': 0.02809935029743241,
#  'vaild RMSLE': 0.13048900094659982,
#  'Training R^2': 0.9973473235784606,
#  'valid R^2 ': 0.8741740270098742}

# %%
gbr_model_tune.best_params_
# Out:
# {'n_estimators': 100,
#  'min_samples_split': 11,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 7,
#  'learning_rate': 0.1}

# %%
gbr_model_tune.best_estimator_
# Out:
# GradientBoostingRegressor(max_depth=7, max_features='sqrt',
#                           min_samples_split=11)

# %%
learning_rate
max_leaf_nodes
'max_depth
max_features
'n_estimators
min_samples_split
min_samples_leaf

# %% [markdown]
# # Build Model Using Both parameter

# %% [markdown]
# ###  Random Forest Classifier
# {'n_estimators': 70,
#  'min_samples_split': 4,
#  'min_samples_leaf': 1,
#  'max_samples': 105,
#  'max_features': 0.5,
#  'max_depth': 30,
#  'bootstrap': True}

# %%
RFR=RandomForestRegressor(n_estimators=70,
                         min_samples_split=4,
                         min_samples_leaf=1,
                          max_samples=105,
                         max_features=0.5,
                         max_depth=30,
                         bootstrap=True)

# %%
RFR.fit(xb_train,y_b_train)
# Out:
# RandomForestRegressor(max_depth=30, max_features=0.5, max_samples=105,
#                       min_samples_split=4, n_estimators=70)

# %%
show_scores(RFR)
# Out:
# {'Training MAE': 18453.263628127694,
#  'Vaild MAE': 20023.331127777772,
#  'Training RMSLE': 0.15850485068220685,
#  'vaild RMSLE': 0.16325425776832653,
#  'Training R^2': 0.8517372786977736,
#  'valid R^2 ': 0.7861697446850056}

# %% [markdown]
# ###  Gradient Boosting Regressor
#
# GradientBoostingRegressor(max_depth=7, max_features='sqrt', min_samples_leaf=2,
#
#                           n_estimators=200)

# %% [markdown]
# GradientBoostingRegressor(max_depth=6, max_features='log2', min_samples_leaf=2,
#                           min_samples_split=10)

# %% [markdown]
# GradientBoostingRegressor(max_depth=7, max_features='sqrt',
#                           min_samples_split=10, n_estimators=200)

# %%
   {'n_estimators': 100,
 'min_samples_split': 11,
 'min_samples_leaf': 1,
 'max_features': 'sqrt',
 'max_depth': 7,
 'learning_rate': 0.1}  ✅

# %%
GBR1=GradientBoostingRegressor(n_estimators=100,
                               max_depth=7,
                               min_samples_leaf=1,
                               max_features='sqrt',
                               min_samples_split=11,
                              learning_rate=0.1)

# %%
GBR2=GradientBoostingRegressor(n_estimators=200,
                               max_depth=7,
                               min_samples_split=11,
                               max_features='sqrt',
                               min_samples_leaf=2,
                              learning_rate=0.1)

# %%
GBR3=GradientBoostingRegressor(max_depth=6,
                               max_features='log2',
                               min_samples_leaf=2, 
                               min_samples_split=10,
                              n_estimators=100,
                              learning_rate=0.1)

# %%
GBR4=GradientBoostingRegressor(max_depth=7,
                          max_features='sqrt',
                         min_samples_leaf=7,
                          min_samples_split=10, 
                          n_estimators=200,
                         learning_rate=0.1)

# %%
xb_train.shape,y_b_train.shape
# Out:
# ((1460, 80), (1460,))

# %%
GBR1.fit(xb_train,y_b_train)
# Out:
# GradientBoostingRegressor(max_depth=7, max_features='sqrt',
#                           min_samples_split=11)

# %%
GBR2.fit(xb_train,y_b_train)
# Out:
# GradientBoostingRegressor(max_depth=7, max_features='sqrt', min_samples_leaf=2,
#                           min_samples_split=11, n_estimators=200)

# %%
GBR3.fit(xb_train,y_b_train)
# Out:
# GradientBoostingRegressor(max_depth=6, max_features='log2', min_samples_leaf=2,
#                           min_samples_split=10)

# %%
GBR4.fit(xb_train,y_b_train)
# Out:
# GradientBoostingRegressor(max_depth=7, max_features='sqrt', min_samples_leaf=7,
#                           min_samples_split=10, n_estimators=200)

# %% [markdown]
# # Prepare for test data

# %%
test_df=pd.read_csv("data_house_prediction/test.csv")

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# ## Change String into Categories For Test data

# %%
def change_int(df):
    # fill value in LotFrontage 
    df.LotFrontage.fillna(df.LotFrontage.mean(),inplace=True)
    # Fill missing value in Alley and change into Number  
    df['Alley'].fillna("NA", inplace=True)
    # Define the mapping
    mapping = {'Grvl': 0, 'Pave': 1, 'NA': 2}
    # Create a new column with the integer values
    df['Alley'] = df['Alley'].map(mapping)
    # Fill Missing value of MasVnrType
    # Fill missing value inplace NA
    df['MasVnrType'].fillna("NA", inplace=True)
    # create a dict to change that 
    mapping={"BrkCmn":0,"BrkFace":1, "CBlock":3,"NA":4,"Stone":5}
    df["MasVnrType"]=df["MasVnrType"].map(mapping)
    # Fill MasVnrArea
    df["MasVnrArea"].fillna(df["MasVnrArea"].median(),inplace=True)
    # mapping and convert into number 
    df["BsmtQual"].fillna("NA",inplace=True)
    mapping ={"Ex":1,
          "Gd":2,
          "TA":3,
          "Fa":4,
          "Po":5,
          "NA":6}
    # Map value in BsmtQual
    df["BsmtQual"]=df["BsmtQual"].map(mapping)
    #Fill BSMTcond 
    df["BsmtCond"].fillna("NA",inplace=True)
    mapping ={"Ex":1,
          "Gd":2,
          "TA":3,
          "Fa":4,
          "Po":5,
          "NA":6}
    # Map value in BsmtQual
    df["BsmtCond"]=df["BsmtCond"].map(mapping)
    # mapping and convert into number 
    df["BsmtExposure"].fillna("NA",inplace=True)
    mapping ={
          "Gd":1,
          "Av":2,
          "Mn":3,
          "No":4,
          "NA":5}
    # Map value in BsmtQual
    df["BsmtExposure"]=df["BsmtExposure"].map(mapping)
    # mapping and convert into number 
    df["BsmtFinType1"].fillna(value="NA",inplace=True)

    # make mapping variable
    mapping={"GLQ":0,
             "ALQ":1,
             "BLQ":2,
             "Rec":3,
             "LwQ":4,
            "Unf":5,
             "NA":6}
    # Map value in BsmtQual
    df["BsmtFinType1"]=df["BsmtFinType1"].map(mapping)
    # mapping and convert into number 
    df["BsmtFinType2"].fillna(value="NA",inplace=True)

    # make mapping variable
    mapping={"GLQ":0,
             "ALQ":1,
             "BLQ":2,
             "Rec":3,
             "LwQ":4,
             "Unf":5,
             "NA":6}
    # Map value in BsmtQual
    df["BsmtFinType2"]=df["BsmtFinType2"].map(mapping)
    # Electrical 
    df.Electrical.fillna("NA",inplace=True)
    mapping={"SBrkr":0,
         "FuseA":1,
         "FuseF":2,
         "FuseP":3,
         "Mix":4,
         "NA":0
        }
    df["Electrical"]=df.Electrical.map(mapping)
    df.FireplaceQu.fillna("NA",inplace=True)
    mapping={"Ex":0,
        "Gd":1,
        "TA":2,
        "Fa":3,
        "Po":4,
        "NA":5}
    df["FireplaceQu"]=df.FireplaceQu.map(mapping)
#     Guarge Type
    df.GarageType.fillna("NA",inplace=True)
    mapping={"2Types":0,
        "Attchd":1,
        "Basment":2,
        "BuiltIn":3,
        "CarPort":4,
        "Detchd":5,
        "NA":6}
    df["GarageType"]=df.GarageType.map(mapping)
    # GarageYrBlt
    df.GarageYrBlt.fillna(df.GarageYrBlt.median(),inplace=True)
    # GarageFinish
    df["GarageFinish"].fillna("NA",inplace=True)
    mapping={"Fin": 0,
         "RFn" :1,
         "Unf": 2,
         "NA" :3}
    df["GarageFinish"]=df["GarageFinish"].map(mapping)
    # GarageQual
    df.GarageQual.fillna("NA",inplace=True)
    mapping={"Ex": 0,
         "Gd": 1,
         "TA": 2,
         "Fa": 3,
         "Po": 4,
         "NA":5}
    df["GarageQual"]=df["GarageQual"].map(mapping)
    # Garage COnd
    df.GarageCond.fillna("NA",inplace=True)
    mapping={"Ex": 0,
         "Gd": 1,
         "TA": 2,
         "Fa": 3,
         "Po": 4,
         "NA":5}
    df["GarageCond"]=df["GarageCond"].map(mapping)
#     PoolQC
    df.PoolQC.fillna("NA",inplace=True)
    mapping={"Ex": 0,
         "Gd": 1,
         "TA": 2,
         "Fa": 3,
         "NA":4}
    df["PoolQC"]=df["PoolQC"].map(mapping)
    df.Fence.fillna("NA",inplace=True)
    mapping={"GdPrv": 0,
         "MnPrv": 1,
         "GdWo": 2,
         "MnWw":3,
         "NA" :4,}
    df["Fence"]=df.Fence.map(mapping)
    # MiscFeature
    df.MiscFeature.fillna("NA",inplace=True)
    mapping={"Elev": 0,
         "Gar2": 1,
         "Othr" :2,
         "Shed":3,
         "TenC":4,
         "NA": 5}
    df["MiscFeature"]=df.MiscFeature.map(mapping)
    for label, content in df.items():
        if pd.isna(content).any():
            if pd.api.types.is_float_dtype(content):
                median_value=df[label].median()
                df[label].fillna(value=median_value,inplace=True)
                
    return df

# %%
def cat_df(df_test_pro):
    for label, content in df_test_pro.items():
        # Check columns which *aren't* numeric
        if not pd.api.types.is_numeric_dtype(content):
            # We add the +1 because pandas encodes missing categories as -1
            df_test_pro[label] = pd.Categorical(content).codes+1
    return df

# %% [markdown]
# ## import test data

# %%
test=pd.read_csv("check_tm.csv")

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1459 non-null   int64
#  3   LotFrontage    1459 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   int64
#  6   Alley          1459 non-null   int64
#  7   LotShape       1459 non-null   int64
#  8   LandContour    1459 non-null   int64
#  9   Utilities      1459 non-null   int64
#  10  LotConfig      1459 non-null   int64
#  11  LandSlope      1459 non-null   int64
#  12  Neighborhood   1459 non-null   int64
#  13  Condition1     1459 non-null   int64
#  14  Condition2     1459 non-null   int64
#  15  BldgType       1459 non-null   int64
#  16  HouseStyle     1459 non-null   int64
#  17  OverallQual    1459 non-null   int64
# ...

# %% [markdown]
# ##  Random Forest Regression Model  Got score (0.1732)

# %%
summit_df["SalePrice"]=RFR.predict(test)

# %%
summit_df=pd.DataFrame(data=test["Id"],index=None)

# %%
summit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         1459 non-null   int64
#  1   SalePrice  1459 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 22.9 KB

# %%
summit_df.to_csv("Summitkaggle/Summit.csv",index=False)

# %% [markdown]
# ##  Gradient Based Regression

# %% [markdown]
# #### 1.

# %%
summit_1=pd.DataFrame(data=test.Id,index=None)

# %%
summit_1["SalePrice"]=GBR1.predict(test)

# %%
summit_1.head()
# Out:
#      Id      SalePrice
# 0  1461  140975.940393
# 1  1462  159609.855711
# 2  1463  188913.239487
# 3  1464  197945.129625
# 4  1465  180749.922751

# %% [markdown]
# ### 2.

# %%
summit_2=pd.DataFrame(data=test.Id,index=None)

# %%
summit_2["SalePrice"]=GBR2.predict(test)

# %% [markdown]
# ### 3.

# %%
summit_3=pd.DataFrame(data=test.Id,index=None)

# %%
summit_3["SalePrice"]=GBR3.predict(test)

# %% [markdown]
# ### 4

# %%
summit_4=pd.DataFrame(data=test.Id,index=None)

# %%
summit_4["SalePrice"]=GBR4.predict(test)

# %%
summit_1.to_csv("Summitkaggle/GBR1.csv",index=False)

# %%
summit_2.to_csv("Summitkaggle/GBR2.csv",index=False)

# %%
summit_3.to_csv("Summitkaggle/GBR3.csv",index=False)

# %%
summit_4.to_csv("Summitkaggle/GBR4.csv",index=False)

# %% [markdown]
# ## Got Score with lowest with GBR (0.13320)
